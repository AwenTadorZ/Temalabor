# %%
import requests
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
url = "https://www.gamestar.hu/site/rss/rss.xml"

# %%
resp = requests.get(url)

# %%
soup = BeautifulSoup(resp.content, features="xml")

# %%
#print(soup.prettify())

# %%
items = soup.findAll("item")

# %%
len(items)
# Out:
# 25

# %%
item = items[0]

# %%
item
# Out:
# <item>
# <title>Magyar fejlesztésű VR-játékban válhattok a sudoku mestereivé</title>
# <link>https://www.gamestar.hu/magyarjatek/magyar-fejlesztesu-vr-jatekban-valhattok-a-sudoku-mestereive-278650.html</link>
# <description>Az Arabian Stones - The VR Sudoku Game pontosan azt kínálja, amit a címe ígér: sudokut VR-ban.</description>
# <author>Csirke</author>
# <category>infopctech</category>
# <pubDate>Tue, 12 May 2020 15:40:49 +0200</pubDate>
# <guid>https://www.gamestar.hu/magyarjatek/magyar-fejlesztesu-vr-jatekban-valhattok-a-sudoku-mestereive-278650.html</guid>
# <enclosure length="2048" type="image/jpeg" url="https://i.cdn29.hu/apix_collect_c/2005/arabian-stones-the-vr-sudoku-game/arabian_stones_the_vr_sudoku_game_screenshot_20200512120905_1_original_390x220_cover.jpg"/>
# </item>

# %%
item.title
# Out:
# <title>Magyar fejlesztésű VR-játékban válhattok a sudoku mestereivé</title>

# %%
item.title.text
# Out:
# 'Magyar fejlesztésű VR-játékban válhattok a sudoku mestereivé'

# %%
author=[]
for item in items:
    author.append(item.author.text)
author
# Out:
# ['Csirke',
#  'PacaGS',
#  'Hunter_GS',
#  'PacaGS',
#  'Gucs',
#  'Csirke',
#  'Csirke',
#  'Csirke',
#  'Csirke',
#  'Csirke',
#  'Csirke',
#  'Hunter_GS',
#  'Csirke',
#  'Hunter_GS',
#  'Csirke',
#  'Szabó Dániel',
#  'Gucs',
#  'Gucs',
#  'Hunter_GS',
#  'Gucs',
#  'Gucs',
#  'Gucs',
#  'Bátky Zoltán',
#  'Buzsik Turner Kriszti',
#  'GSO']

# %%
plt.figure(figsize=(13,5))

plt.style.use("ggplot")

plt.xticks(rotation=45)
plt.tick_params(axis='x', colors='blue', length=0)
plt.tick_params(labelright=True)


plt.ylabel("Cikkek száma",fontsize=12,color="black")
plt.xlabel("Cikk szerző",fontsize=12,color="black")
plt.title("Cikkek száma szerzőnként",fontsize=16)
plt.hist(author, bins=len(author), color="lightblue",edgecolor="black")


plt.show()

# %%
category=[]
for item in items:
    category.append(item.category.text)
category
# Out:
# ['infopctech',
#  'infopctech',
#  'infopctech',
#  'infopctech',
#  'infopctech',
#  'infopctech',
#  'infopctech',
#  'infopctech',
#  'infopctech',
#  'infopctech',
#  'infopctech',
#  'infopctech',
#  'infopctech',
#  'infopctech',
#  'infopctech',
#  'infopctech',
#  'infopctech',
#  'infopctech',
#  'infopctech',
#  'infopctech',
#  'infopctech',
#  'infopctech',
#  'infopctech',
#  'infopctech',
#  'infopctech']

# %%
link=[]
for item in items:
    link.append(item.link.text)
link
# Out:
# ['https://www.gamestar.hu/magyarjatek/magyar-fejlesztesu-vr-jatekban-valhattok-a-sudoku-mestereive-278650.html',
#  'https://www.gamestar.hu/uzlet/igy-indulnak-majd-a-playstation-sajat-jatekai-a-ps5-on-278660.html',
#  'https://www.gamestar.hu/masvilag/megis-mozikba-kerulhet-az-uj-mutansok-278623.html',
#  'https://www.gamestar.hu/uzlet/oktoberben-johet-a-playstation-5-megjelenes-278657.html',
#  'https://www.gamestar.hu/valodi-jatekok/te-talalnal-helyet-a-polcodon-a-star-wars-the-clone-wars-egyik-legnepszerubb-karakterenek-278604.html',
#  'https://www.gamestar.hu/masvilag/michael-douglas-szerint-hamarosan-hallani-fogunk-a-hangya-3-rol-278649.html',
#  'https://www.gamestar.hu/magyarjatek/cyberpunk-stilusu-multis-fps-en-dolgozik-egy-magyar-fejleszto-ti-is-kiprobalhattok-278646.html',
#  'https://www.gamestar.hu/hir/az-assassins-creed-valhalla-minimum-30-fps-sel-fog-futni-4k-ban-xbox-series-x-en-20200512-278642.html',
# ...

# %%
#print("gamestar" in link[3])
gamestar=0
pcworld=0
puliwood=0
egyéb=0
for i in link:
    if "gamestar" in i:
      gamestar+=1
    elif "pcworld" in i:
        pcworld+=1
    elif "puliwood" in i:
        puliwood+=1
    else:
        egyéb+=1
gamestar
pcworld
puliwood
egyéb
# Out:
# 0

# %%
plt.figure(figsize=(6,6))


labels = ["Gamestar", "PCworld","Puliwood", "egyéb"]
colors = ["#f5e940", "pink", "red","lightblue"]
explode=(0.1,.1,.1,.1)

plt.pie([gamestar, pcworld, puliwood, egyéb], labels=labels, colors=colors, autopct="%2.f %%", explode=explode,
        textprops={'fontsize': 14})
plt.title("Cikkek forrásának eloszlása",fontsize=16)

plt.legend([gamestar,pcworld,puliwood,egyéb],prop={"size":14},bbox_to_anchor=(1.4,1),title="Cikkek száma")

plt.show()

# %%
resp = requests.get(link[0])
soup = BeautifulSoup(resp.content, features="xml")
print(soup.prettify())
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <!DOCTYPE html>
# <!-- Dedsec https://goo.gl/aFRx9J -->
# <html lang="hu">
#  <head>
#   <title>
#    Magyar fejlesztésű VR-játékban válhattok a sudoku mestereivé - Hír - GameStar
#   </title>
#   <meta content="Az Arabian Stones - The VR Sudoku Game pontosan azt kínálja, amit a címe ígér: sudokut VR-ban." name="description"/>
#   <meta content="" name="keywords"/>
#   <base href="https://www.gamestar.hu/">
#    <link href="https://www.gamestar.hu/magyarjatek/magyar-fejlesztesu-vr-jatekban-valhattok-a-sudoku-mestereive-278650.html" rel="canonical"/>
#    <meta charset="utf-8"/>
#    <meta content="width=device-width, initial-scale=1.0, maximum-scale=5.0, user-scalable=yes" name="viewport"/>
#    <meta content="yes" name="apple-mobile-web-app-capable"/>
#    <link as="font" href="/site/fonts/KFOlCnqEu92Fr1MmSU5fChc4EsA.woff2" rel="preload" type="font/woff2">
# ...

# %%
table = soup.find("div", class_="content")
table
# Out:
# <div class="content">
# <p>
# <p>Az elmúlt pár évben elég népszerű lett a sudoku, egy csomó napilapban megtalálható mellékletként, illetve telefonos játékból is van belőle ezer és egy. Egy magyar <span>szoftverfejlesztő</span>, név szerint <span>Gyurisán János most úgy érezte, a klasszikus logikai játék VR-ban is megállná a helyét.</span></p>
# <p>Így született meg az Arabian Stones - The VR Sudoku Game. <span>János régóta szeretett volna videojátékokkal foglalkozni, de sokáig nem tudta elérni, hogy végig is vigyen egy saját projektet. Végül úgy határozott, hogy valami egyszerűbbel kezd neki a fejlesztésnek. Kíváncsian várjuk, legközelebb mivel rukkol majd elő, mert a VR-sudoku játék első szárnypróbálgatásnak több mint ígéretes. </span></p>
# ...

# %%
rows = table.find_all("p")
columns = [v.text for v in rows[0].find_all("p")]
print(columns)
# Out:
# ['Az elmúlt pár évben elég népszerű lett a\xa0sudoku, egy csomó napilapban megtalálható mellékletként, illetve telefonos játékból is van belőle ezer és egy. Egy magyar szoftverfejlesztő, név szerint\xa0Gyurisán János most úgy érezte, a klasszikus\xa0logikai játék VR-ban is megállná a helyét.', 'Így született meg az\xa0Arabian Stones - The VR Sudoku Game.\xa0János régóta szeretett volna videojátékokkal foglalkozni, de sokáig nem tudta elérni, hogy végig is vigyen egy saját projektet. Végül úgy határozott, hogy valami egyszerűbbel kezd neki a fejlesztésnek. Kíváncsian várjuk, legközelebb mivel rukkol majd elő, mert a VR-sudoku játék első szárnypróbálgatásnak több mint ígéretes.\xa0', 'Az Arabian Stones - The VR Sudoku Game nevezetű játékot a Steamen éritek el, ára egészen pontosan 3,29 euró - azaz nagyjából 1150 forint.']

# %%
for i in columns:
    print(i)
# Out:
# Az elmúlt pár évben elég népszerű lett a sudoku, egy csomó napilapban megtalálható mellékletként, illetve telefonos játékból is van belőle ezer és egy. Egy magyar szoftverfejlesztő, név szerint Gyurisán János most úgy érezte, a klasszikus logikai játék VR-ban is megállná a helyét.
# Így született meg az Arabian Stones - The VR Sudoku Game. János régóta szeretett volna videojátékokkal foglalkozni, de sokáig nem tudta elérni, hogy végig is vigyen egy saját projektet. Végül úgy határozott, hogy valami egyszerűbbel kezd neki a fejlesztésnek. Kíváncsian várjuk, legközelebb mivel rukkol majd elő, mert a VR-sudoku játék első szárnypróbálgatásnak több mint ígéretes.
# Az Arabian Stones - The VR Sudoku Game nevezetű játékot a Steamen éritek el, ára egészen pontosan 3,29 euró - azaz nagyjából 1150 forint.

# %%
print(i)
len(i.split())
# Out:
# Az Arabian Stones - The VR Sudoku Game nevezetű játékot a Steamen éritek el, ára egészen pontosan 3,29 euró - azaz nagyjából 1150 forint.
# 24

# %%
a=0
for i in columns:
    a+=len(i.split())
print(a)
# Out:
# 121

# %%
SzavakSzama=[]
db=0
j=0
while j<len(link):
    db=0
    resp = requests.get(link[j])
    soup = BeautifulSoup(resp.content, features="xml")
    table = soup.find("div", class_="content")
    rows = table.find_all("p")
    columns = [v.text for v in rows[0].find_all("p")]
    for i in columns:
        db+=len(i.split())   
    SzavakSzama.append(db)
    j+=1
        
print(SzavakSzama)
# Out:
# [121, 199, 152, 218, 147, 167, 115, 233, 141, 226, 772, 140, 196, 262, 991, 288, 779, 268, 157, 165, 213, 143, 2973, 2284, 235]

# %%
len(SzavakSzama)
# Out:
# 25

# %%
plt.figure(figsize=(13,5))

bins = [0,100,200,300,400,500,600,700,800,900,1000]

plt.hist(SzavakSzama,bins=bins, color="blue",edgecolor="white")


plt.xticks(bins)
plt.xlabel("Szavak száma",fontsize=12,color="black")
plt.ylabel("Cikk szám",fontsize=12,color="black")
plt.title("Szavak száma cikkenként",fontsize=16)

plt.tick_params(labeltop=True, labelright=True)


plt.show()

# %%
print(author, SzavakSzama)
# Out:
# ['Csirke', 'PacaGS', 'Hunter_GS', 'PacaGS', 'Gucs', 'Csirke', 'Csirke', 'Csirke', 'Csirke', 'Csirke', 'Csirke', 'Hunter_GS', 'Csirke', 'Hunter_GS', 'Csirke', 'Szabó Dániel', 'Gucs', 'Gucs', 'Hunter_GS', 'Gucs', 'Gucs', 'Gucs', 'Bátky Zoltán', 'Buzsik Turner Kriszti', 'GSO'] [121, 199, 152, 218, 147, 167, 115, 233, 141, 226, 772, 140, 196, 262, 991, 288, 779, 268, 157, 165, 213, 143, 2973, 2284, 235]

# %%
for i in author:
    print(i)
# Out:
# Csirke
# PacaGS
# Hunter_GS
# PacaGS
# Gucs
# Csirke
# Csirke
# Csirke
# Csirke
# Csirke
# Csirke
# Hunter_GS
# Csirke
# Hunter_GS
# Csirke
# Szabó Dániel
# Gucs
# Gucs
# Hunter_GS
# Gucs
# Gucs
# Gucs
# Bátky Zoltán
# Buzsik Turner Kriszti
# GSO

# %%
Szerzo_N=[]
Szerzo_Sz=[]

i=0
k=0

while i<len(author):
    k=0
    if i==0:
        Szerzo_N.append(author[i])
        Szerzo_Sz.append(SzavakSzama[i])
        i+=1
    else:
        while k<len(Szerzo_N):
            if Szerzo_N[k] != author[i]:
                uj_e="uj"
                k+=1
            else:
                uj_e="nem_uj"
                Szerzo_Sz[k]=Szerzo_Sz[k]+SzavakSzama[i]
                break
        if uj_e=="uj":
            Szerzo_N.append(author[i])
            Szerzo_Sz.append(SzavakSzama[i])
            i+=1
        else:
            i+=1
                
        
print(Szerzo_N)
print(Szerzo_Sz)
# Out:
# ['Csirke', 'PacaGS', 'Hunter_GS', 'Gucs', 'Szabó Dániel', 'Bátky Zoltán', 'Buzsik Turner Kriszti', 'GSO']
# [2962, 417, 711, 1715, 288, 2973, 2284, 235]

# %%
plt.figure(figsize=(9,9))
colors = ["lightgrey", "lightblue","red","green", "pink","lime","purple", "yellow","blue", "lightgreen","cyan","orange" ,"grey"]

explode=[.4]*len(Szerzo_N)
plt.pie(Szerzo_Sz, labels=Szerzo_N, colors=colors, autopct="%2.f %%", explode=explode, shadow=True,radius=2,
        textprops={'fontsize': 14})

plt.axis("equal")
plt.legend(Szerzo_Sz,bbox_to_anchor=(1.55,1),title="Szavak Száma",prop={"size":20})


plt.title("Leírt szavak száma Szerzőnként",fontsize=18)
plt.show()

# %%
v=[260, 136, 167, 172, 867, 151, 118, 184, 102, 186, 1040]
v[3]=v[3]+300
print(v)
# Out:
# [260, 136, 167, 472, 867, 151, 118, 184, 102, 186, 1040]

# %%
print(Szerzo_N)
print(author.count(Szerzo_N[0]))
# Out:
# ['Csirke', 'PacaGS', 'Hunter_GS', 'Gucs', 'Szabó Dániel', 'Bátky Zoltán', 'Buzsik Turner Kriszti', 'GSO']
# 9

# %%
AtlagSzo=[]
m=0
while m < len(Szerzo_N):
    AtlagSzo.append("{:.2f}".format(Szerzo_Sz[m]/(author.count(Szerzo_N[m]))))
    m+=1
print(AtlagSzo)
# Out:
# ['329.11', '208.50', '177.75', '285.83', '288.00', '2973.00', '2284.00', '235.00']

# %%
plt.figure(figsize=(9,9))
colors = ["lightgrey", "lightblue","red","green", "pink","lime","purple", "yellow","blue", "lightgreen","cyan","orange" ,"grey"]

explode=[.3]*len(Szerzo_N)
plt.pie(AtlagSzo, labels=Szerzo_N, colors=colors, autopct="%2.f %%", explode=explode, shadow=True,radius=3,
        textprops={'fontsize': 14})

plt.axis("equal")
plt.legend(AtlagSzo,bbox_to_anchor=(1.55,1),title="Szavak átlaga",prop={"size":20})


plt.title("Leírt szavak átlaga Szerzőnként",fontsize=18)
plt.show()
